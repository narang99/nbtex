# %%
#export
from pytex.Variables import Var

# %%
#export 
class OperatorSymbols():
    def __init__(self):
        pass
    @property
    def leq(self):
        return Var(r'\leq')
    @property
    def leqq(self):
        return Var(r'\leqq')
    @property
    def leqslant(self):
        return Var(r'\leqslant')
    @property
    def geq(self):
        return Var(r'\geq')
    @property
    def geqq(self):
        return Var(r'\geqq')
    @property
    def geqslant(self):
        return Var(r'\geqslant')
    @property
    def nless(self):
        return Var(r'\nless')
    @property
    def nleq(self):
        return Var(r'\nleq')
    @property
    def lneq(self):
        return Var(r'\lneq')
    @property
    def nleqq(self):
        return Var(r'\nleqq')
    @property
    def lneqq(self):
        return Var(r'\lneqq')
    @property
    def lvertneqq(self):
        return Var(r'\lvertneqq')
    @property
    def nleqslant(self):
        return Var(r'\nleqslant')
    @property
    def ngtr(self):
        return Var(r'\ngtr')
    @property
    def ngeq(self):
        return Var(r'\ngeq')
    @property
    def gneq(self):
        return Var(r'\gneq')
    @property
    def ngeqq(self):
        return Var(r'\ngeqq')
    @property
    def gneqq(self):
        return Var(r'\gneqq')
    @property
    def gvertneqq(self):
        return Var(r'\gvertneqq')
    @property
    def ngeqslant(self):
        return Var(r'\ngeqslant')
    @property
    def vartriangleleft(self):
        return Var(r'\vartriangleleft')
    @property
    def trianglelefteq(self):
        return Var(r'\trianglelefteq')
    @property
    def lesssim(self):
        return Var(r'\lesssim')
    @property
    def lessapprox(self):
        return Var(r'\lessapprox')
    @property
    def prec(self):
        return Var(r'\prec')
    @property
    def preceq(self):
        return Var(r'\preceq')
    @property
    def precsim(self):
        return Var(r'\precsim')
    @property
    def precapprox(self):
        return Var(r'\precapprox')
    @property
    def vartriangleright(self):
        return Var(r'\vartriangleright')
    @property
    def trianglerighteq(self):
        return Var(r'\trianglerighteq')
    @property
    def gtrsim(self):
        return Var(r'\gtrsim')
    @property
    def gtrapprox(self):
        return Var(r'\gtrapprox')
    @property
    def succ(self):
        return Var(r'\succ')
    @property
    def succeq(self):
        return Var(r'\succeq')
    @property
    def succsim(self):
        return Var(r'\succsim')
    @property
    def succapprox(self):
        return Var(r'\succapprox')
    @property
    def ntriangleleft(self):
        return Var(r'\ntriangleleft')
    @property
    def ntrianglelefteq(self):
        return Var(r'\ntrianglelefteq')
    @property
    def lnsim(self):
        return Var(r'\lnsim')
    @property
    def lnapprox(self):
        return Var(r'\lnapprox')
    @property
    def nprec(self):
        return Var(r'\nprec')
    @property
    def npreceq(self):
        return Var(r'\npreceq')
    @property
    def precnsim(self):
        return Var(r'\precnsim')
    @property
    def precnapprox(self):
        return Var(r'\precnapprox')
    @property
    def ntriangleright(self):
        return Var(r'\ntriangleright')
    @property
    def ntrianglerighteq(self):
        return Var(r'\ntrianglerighteq')
    @property
    def gnsim(self):
        return Var(r'\gnsim')
    @property
    def gnapprox(self):
        return Var(r'\gnapprox')
    @property
    def nsucc(self):
        return Var(r'\nsucc')
    @property
    def nsucceq(self):
        return Var(r'\nsucceq')
    @property
    def succnsim(self):
        return Var(r'\succnsim')
    @property
    def succnapprox(self):
        return Var(r'\succnapprox')
    @property
    def eqslantless(self):
        return Var(r'\eqslantless')
    @property
    def lessgtr(self):
        return Var(r'\lessgtr')
    @property
    def lesseqgtr(self):
        return Var(r'\lesseqgtr')
    @property
    def lesseqqgtr(self):
        return Var(r'\lesseqqgtr')
    @property
    def eqslantgtr(self):
        return Var(r'\eqslantgtr')
    @property
    def gtrless(self):
        return Var(r'\gtrless')
    @property
    def gtreqless(self):
        return Var(r'\gtreqless')
    @property
    def gtreqqless(self):
        return Var(r'\gtreqqless')
    @property
    def ll(self):
        return Var(r'\ll')
    @property
    def lll(self):
        return Var(r'\lll')
    @property
    def lessdot(self):
        return Var(r'\lessdot')
    @property
    def preccurlyeq(self):
        return Var(r'\preccurlyeq')
    @property
    def curlyeqprec(self):
        return Var(r'\curlyeqprec')
    @property
    def gg(self):
        return Var(r'\gg')
    @property
    def ggg(self):
        return Var(r'\ggg')
    @property
    def gtrdot(self):
        return Var(r'\gtrdot')
    @property
    def succcurlyeq(self):
        return Var(r'\succcurlyeq')
    @property
    def curlyeqsucc(self):
        return Var(r'\curlyeqsucc')
    @property
    def neq(self):
        return Var(r'\neq')
    @property
    def equiv(self):
        return Var(r'\equiv')
    @property
    def thickapprox(self):
        return Var(r'\thickapprox')
    @property
    def approx(self):
        return Var(r'\approx')
    @property
    def approxeq(self):
        return Var(r'\approxeq')
    @property
    def cong(self):
        return Var(r'\cong')
    @property
    def ncong(self):
        return Var(r'\ncong')
    @property
    def sim(self):
        return Var(r'\sim')
    @property
    def thicksim(self):
        return Var(r'\thicksim')
    @property
    def nsim(self):
        return Var(r'\nsim')
    @property
    def simeq(self):
        return Var(r'\simeq')
    @property
    def backsim(self):
        return Var(r'\backsim')
    @property
    def backsimeq(self):
        return Var(r'\backsimeq')
    @property
    def eqsim(self):
        return Var(r'\eqsim')
    @property
    def doteq(self):
        return Var(r'\doteq')
    @property
    def div(self):
        return Var(r'\div')
    @property
    def doteqdot(self):
        return Var(r'\doteqdot')
    @property
    def fallingdotseq(self):
        return Var(r'\fallingdotseq')
    @property
    def risingdotseq(self):
        return Var(r'\risingdotseq')
    @property
    def triangleq(self):
        return Var(r'\triangleq')
    @property
    def circeq(self):
        return Var(r'\circeq')
    @property
    def eqcirc(self):
        return Var(r'\eqcirc')
    @property
    def bumpeq(self):
        return Var(r'\bumpeq')
    @property
    def Bumpeq(self):
        return Var(r'\Bumpeq')
    @property
    def asymp(self):
        return Var(r'\asymp')
    @property
    def mid(self):
        return Var(r'\mid')
    @property
    def shortmid(self):
        return Var(r'\shortmid')
    @property
    def vdash(self):
        return Var(r'\vdash')
    @property
    def dashv(self):
        return Var(r'\dashv')
    @property
    def Vdash(self):
        return Var(r'\Vdash')
    @property
    def parallel(self):
        return Var(r'\parallel')
    @property
    def shortparallel(self):
        return Var(r'\shortparallel')
    @property
    def vDash(self):
        return Var(r'\vDash')
    @property
    def Vvdash(self):
        return Var(r'\Vvdash')
    @property
    def models(self):
        return Var(r'\models')
    @property
    def nmid(self):
        return Var(r'\nmid')
    @property
    def nshortmid(self):
        return Var(r'\nshortmid')
    @property
    def nvdash(self):
        return Var(r'\nvdash')
    @property
    def nVdash(self):
        return Var(r'\nVdash')
    @property
    def nparallel(self):
        return Var(r'\nparallel')
    @property
    def nshortparallel(self):
        return Var(r'\nshortparallel')
    @property
    def nvDash(self):
        return Var(r'\nvDash')
    @property
    def nVDash(self):
        return Var(r'\nVDash')

# %%
#export
Operator = OperatorSymbols()

# %%
! python3 ./notebook2script.py Operators.ipynb

# %%
" TESTS "

# %%
from exp.SymbolsExtractor import getProps, getWrappedProps
from exp.Variables import wrap

# %%
k = OperatorSymbols()
"copy paste the output and execute in markdown or code cell " 
getWrappedProps(OperatorSymbols, 'k')

# %%
wrap(k.leq | k.leqq | k.leqslant | k.geq | k.geqq | k.geqslant | k.nless | k.nleq | k.lneq | k.nleqq | k.lneqq | k.lvertneqq | k.nleqslant | k.ngtr | k.ngeq | k.gneq | k.ngeqq | k.gneqq | k.gvertneqq | k.ngeqslant | k.vartriangleleft | k.trianglelefteq | k.lesssim | k.lessapprox | k.prec | k.preceq | k.precsim | k.precapprox | k.vartriangleright | k.trianglerighteq | k.gtrsim | k.gtrapprox | k.succ | k.succeq | k.succsim | k.succapprox | k.ntriangleleft | k.ntrianglelefteq | k.lnsim | k.lnapprox | k.nprec | k.npreceq | k.precnsim | k.precnapprox | k.ntriangleright | k.ntrianglerighteq | k.gnsim | k.gnapprox | k.nsucc | k.nsucceq | k.succnsim | k.succnapprox | k.eqslantless | k.lessgtr | k.lesseqgtr | k.lesseqqgtr | k.eqslantgtr | k.gtrless | k.gtreqless | k.gtreqqless | k.ll | k.lll | k.lessdot | k.preccurlyeq | k.curlyeqprec | k.gg | k.ggg | k.gtrdot | k.succcurlyeq | k.curlyeqsucc | k.neq | k.equiv | k.thickapprox | k.approx | k.approxeq | k.cong | k.ncong | k.sim | k.thicksim | k.nsim | k.simeq | k.backsim | k.backsimeq | k.eqsim | k.doteq | k.div | k.doteqdot | k.fallingdotseq | k.risingdotseq | k.triangleq | k.circeq | k.eqcirc | k.bumpeq | k.Bumpeq | k.asymp | k.mid | k.shortmid | k.vdash | k.dashv | k.Vdash | k.parallel | k.shortparallel | k.vDash | k.Vvdash | k.models | k.nmid | k.nshortmid | k.nvdash | k.nVdash | k.nparallel | k.nshortparallel | k.nvDash | k.nVDash )

# %%
" EXTRACT FROM WEBSITE "

# %%
from exp.SymbolsExtractor import getDefs, getNameSym

# %%
pasta = r"""
     <
    ≤ {\displaystyle \leq } \leq \leq
      {\displaystyle \ } \ 
    ≦ {\displaystyle \leqq } \leqq \leqq
      {\displaystyle \ } \ 
      {\displaystyle \ } \ 
    ⩽ {\displaystyle \leqslant } \leqslant \leqslant

	

    > {\displaystyle >} > >
    ≥ {\displaystyle \geq } \geq \geq
      {\displaystyle \ } \ 
    ≧ {\displaystyle \geqq } \geqq \geqq
      {\displaystyle \ } \ 
      {\displaystyle \ } \ 
    ⩾ {\displaystyle \geqslant } \geqslant \geqslant

	

    ≮ {\displaystyle \nless } \nless \nless
    ≰ {\displaystyle \nleq } \nleq \nleq
    ⪇ {\displaystyle \lneq } \lneq \lneq
    ≰ {\displaystyle \nleqq } \nleqq \nleqq
    ≨ {\displaystyle \lneqq } \lneqq \lneqq
    ≨ {\displaystyle \lvertneqq } \lvertneqq \lvertneqq
    ⪇ {\displaystyle \nleqslant } \nleqslant \nleqslant

	

    ≯ {\displaystyle \ngtr } \ngtr \ngtr
    ≱ {\displaystyle \ngeq } \ngeq \ngeq
    ⪈ {\displaystyle \gneq } \gneq \gneq
    ≱ {\displaystyle \ngeqq } \ngeqq \ngeqq
    ≩ {\displaystyle \gneqq } \gneqq \gneqq
    ≩ {\displaystyle \gvertneqq } \gvertneqq \gvertneqq
    ⪈ {\displaystyle \ngeqslant } \ngeqslant \ngeqslant

    ⊲ {\displaystyle \vartriangleleft } \vartriangleleft \vartriangleleft
    ⊴ {\displaystyle \trianglelefteq } \trianglelefteq \trianglelefteq
    ≲ {\displaystyle \lesssim } \lesssim \lesssim
    ⪅ {\displaystyle \lessapprox } \lessapprox \lessapprox
    ≺ {\displaystyle \prec } \prec \prec
    ⪯ {\displaystyle \preceq } \preceq \preceq
    ≾ {\displaystyle \precsim } \precsim \precsim
    ⪷ {\displaystyle \precapprox } \precapprox \precapprox

	

    ⊳ {\displaystyle \vartriangleright } \vartriangleright \vartriangleright
    ⊵ {\displaystyle \trianglerighteq } \trianglerighteq \trianglerighteq
    ≳ {\displaystyle \gtrsim } \gtrsim \gtrsim
    ⪆ {\displaystyle \gtrapprox } \gtrapprox \gtrapprox
    ≻ {\displaystyle \succ } \succ \succ
    ⪰ {\displaystyle \succeq } \succeq \succeq
    ≿ {\displaystyle \succsim } \succsim \succsim
    ⪸ {\displaystyle \succapprox } \succapprox \succapprox

	

    ⋪ {\displaystyle \ntriangleleft } \ntriangleleft \ntriangleleft
    ⋬ {\displaystyle \ntrianglelefteq } \ntrianglelefteq \ntrianglelefteq
    ⋦ {\displaystyle \lnsim } \lnsim \lnsim
    ⪉ {\displaystyle \lnapprox } \lnapprox \lnapprox
    ⊀ {\displaystyle \nprec } \nprec \nprec
    ⋠ {\displaystyle \npreceq } \npreceq \npreceq
    ⋨ {\displaystyle \precnsim } \precnsim \precnsim
    ⪹ {\displaystyle \precnapprox } \precnapprox \precnapprox

	

    ⋫ {\displaystyle \ntriangleright } \ntriangleright \ntriangleright
    ⋭ {\displaystyle \ntrianglerighteq } \ntrianglerighteq \ntrianglerighteq
    ⋧ {\displaystyle \gnsim } \gnsim \gnsim
    ⪊ {\displaystyle \gnapprox } \gnapprox \gnapprox
    ⊁ {\displaystyle \nsucc } \nsucc \nsucc
    ⋡ {\displaystyle \nsucceq } \nsucceq \nsucceq
    ⋩ {\displaystyle \succnsim } \succnsim \succnsim
    ⪺ {\displaystyle \succnapprox } \succnapprox \succnapprox

    ⪕ {\displaystyle \eqslantless } \eqslantless \eqslantless
    ≶ {\displaystyle \lessgtr } \lessgtr \lessgtr
    ⋚ {\displaystyle \lesseqgtr } \lesseqgtr \lesseqgtr
    ⪋ {\displaystyle \lesseqqgtr } \lesseqqgtr \lesseqqgtr

	

    ⪖ {\displaystyle \eqslantgtr } \eqslantgtr \eqslantgtr
    ≷ {\displaystyle \gtrless } \gtrless \gtrless
    ⋛ {\displaystyle \gtreqless } \gtreqless \gtreqless
    ⪌ {\displaystyle \gtreqqless } \gtreqqless \gtreqqless

	

    ≪ {\displaystyle \ll } \ll \ll
    ⋘ {\displaystyle \lll } \lll \lll
    ⋖ {\displaystyle \lessdot } \lessdot \lessdot
    ≼ {\displaystyle \preccurlyeq } \preccurlyeq \preccurlyeq
    ⋞ {\displaystyle \curlyeqprec } \curlyeqprec \curlyeqprec

	

    ≫ {\displaystyle \gg } \gg \gg
    ⋙ {\displaystyle \ggg } \ggg \ggg
    ⋗ {\displaystyle \gtrdot } \gtrdot \gtrdot
    ≽ {\displaystyle \succcurlyeq } \succcurlyeq \succcurlyeq
    ⋟ {\displaystyle \curlyeqsucc } \curlyeqsucc \curlyeqsucc
"""

# %%
getDefs(getNameSym(pasta))

# %%
pasta2 = r"""
     = =
    ≠ {\displaystyle \neq } \neq \neq
    ≡ {\displaystyle \equiv } \equiv \equiv
    ≈ {\displaystyle \thickapprox } \thickapprox \thickapprox
    ≈ {\displaystyle \approx } \approx \approx
    ≊ {\displaystyle \approxeq } \approxeq \approxeq
    ≅ {\displaystyle \cong } \cong \cong
    ≆ {\displaystyle \ncong } \ncong \ncong

	

    ∼ {\displaystyle \sim } \sim \sim
    ∼ {\displaystyle \thicksim } \thicksim \thicksim
    ≁ {\displaystyle \nsim } \nsim \nsim
    ≃ {\displaystyle \simeq } \simeq \simeq
    ∽ {\displaystyle \backsim } \backsim \backsim
    ⋍ {\displaystyle \backsimeq } \backsimeq \backsimeq
    ≂ {\displaystyle \eqsim } {\displaystyle \eqsim } \eqsim

	

    ≐ {\displaystyle \doteq } \doteq \doteq
    ÷ {\displaystyle \div } \div \div
    ≑ {\displaystyle \doteqdot } \doteqdot \doteqdot
    ≒ {\displaystyle \fallingdotseq } \fallingdotseq \fallingdotseq
    ≓ {\displaystyle \risingdotseq } \risingdotseq \risingdotseq

	

    ≜ {\displaystyle \triangleq } \triangleq \triangleq
    ≗ {\displaystyle \circeq } \circeq \circeq
    ≖ {\displaystyle \eqcirc } \eqcirc \eqcirc
    ≏ {\displaystyle \bumpeq } \bumpeq \bumpeq
    ≎ {\displaystyle \Bumpeq } \Bumpeq \Bumpeq
    ≍ {\displaystyle \asymp } \asymp \asymp

    ∣ {\displaystyle \mid } \mid \mid
    ∣ {\displaystyle \shortmid } \shortmid \shortmid
    ⊢ {\displaystyle \vdash } \vdash \vdash
    ⊣ {\displaystyle \dashv } \dashv \dashv
    ⊩ {\displaystyle \Vdash } \Vdash \Vdash
      {\displaystyle \ } \ 

	

    ∥ {\displaystyle \parallel } \parallel \parallel
    ∥ {\displaystyle \shortparallel } \shortparallel \shortparallel
    ⊨ {\displaystyle \vDash } \vDash \vDash
      {\displaystyle \ } \ 
    ⊪ {\displaystyle \Vvdash } \Vvdash \Vvdash
    ⊨ {\displaystyle \models } \models \models

	

    ∤ {\displaystyle \nmid } \nmid \nmid
    ∤ {\displaystyle \nshortmid } \nshortmid \nshortmid
    ⊬ {\displaystyle \nvdash } \nvdash \nvdash
      {\displaystyle \ } \ 
    ⊮ {\displaystyle \nVdash } \nVdash \nVdash
      {\displaystyle \ } \ 

	

    ∦ {\displaystyle \nparallel } \nparallel \nparallel
    ∦ {\displaystyle \nshortparallel } \nshortparallel \nshortparallel
    ⊭ {\displaystyle \nvDash } \nvDash \nvDash
      {\displaystyle \ } \ 
    ⊯ {\displaystyle \nVDash } \nVDash \nVDash
"""

# %%
getDefs(getNameSym(pasta2))
