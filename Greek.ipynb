# %%
#export
from pytex.Variables import makeVar, Var

# %% [markdown]
# **NOTE:** Symbols not supported by Jupyter Notebook:
# 1. \Alpha
# 2. \Beta

# %%
from pytex.Variables import wrap
# wrap(pls.pi | pls.Pi | pls.alpha | pls.beta | pls.gamma | pls.delta | pls.Delta | pls.epsilon | pls.zeta)

# %%
wrap(pls.varepsilon | pls.eta | pls.theta | pls.vartheta | pls.Theta | pls.iota | pls.kappa | pls.lambd | pls.mu)

# %%
wrap(pls.pi)

# %%
#export 
class GreekSymbols():
    def __init__(self):
        pass
    @property
    def beta(self):
        return Var(r'\beta')
    @property
    def gamma(self):
        return Var(r'\gamma')
    @property
    def delta(self):
        return Var(r'\delta')
    @property
    def epsilon(self):
        return Var(r'\epsilon')
    @property
    def zeta(self):
        return Var(r'\zeta')
    @property
    def eta(self):
        return Var(r'\eta')
    @property
    def theta(self):
        return Var(r'\theta')
    @property
    def iota(self):
        return Var(r'\iota')
    @property
    def kappa(self):
        return Var(r'\kappa')
    @property
    def lambd(self):
        return Var(r'\lambda')
    @property
    def mu(self):
        return Var(r'\mu')
    @property
    def nu(self):
        return Var(r'\nu')
    @property
    def xi(self):
        return Var(r'\xi')
    @property
    def mathrm(self):
        return Var(r'\mathrm')
    @property
    def pi(self):
        return Var(r'\pi')
    @property
    def rho(self):
        return Var(r'\rho')
    @property
    def sigma(self):
        return Var(r'\sigma')
    @property
    def tau(self):
        return Var(r'\tau')
    @property
    def upsilon(self):
        return Var(r'\upsilon')
    @property
    def phi(self):
        return Var(r'\phi')
    @property
    def chi(self):
        return Var(r'\chi')
    @property
    def psi(self):
        return Var(r'\psi')
    @property
    def omega(self):
        return Var(r'\omega')
    @property
    def varepsilon(self):
        return Var(r'\varepsilon')
    @property
    def vartheta(self):
        return Var(r'\vartheta')
    @property
    def varkappa(self):
        return Var(r'\varkappa')
    @property
    def varpi(self):
        return Var(r'\varpi')
    @property
    def varrho(self):
        return Var(r'\varrho')
    @property
    def varphi(self):
        return Var(r'\varphi')
    @property
    def varsigma(self):
        return Var(r'\varsigma')
    @property
    def Gamma(self):
        return Var(r'\Gamma')
    @property
    def Delta(self):
        return Var(r'\Delta')
    @property
    def Theta(self):
        return Var(r'\Theta')
    @property
    def Lambda(self):
        return Var(r'\Lambda')
    @property
    def Upsilon(self):
        return Var(r'\Upsilon')
    @property
    def Xi(self):
        return Var(r'\Xi')
    @property
    def Phi(self):
        return Var(r'\Phi')
    @property
    def Pi(self):
        return Var(r'\Pi')
    @property
    def Psi(self):
        return Var(r'\Psi')
    @property
    def Sigma(self):
        return Var(r'\Sigma')
    @property
    def Omega(self):
        return Var(r'\Omega')
    @property
    def digamma(self):
        return Var(r'\digamma')
    @property
    def aleph(self):
        return Var(r'\aleph')
    @property
    def beth(self):
        return Var(r'\beth')
    @property
    def gimel(self):
        return Var(r'\gimel')
    @property
    def daleth(self):
        return Var(r'\daleth')
    @property
    def forall(self):
        return Var(r'\forall')
    @property
    def exists(self):
        return Var(r'\exists')
    @property
    def nexists(self):
        return Var(r'\nexists')
    @property
    def Finv(self):
        return Var(r'\Finv')
    @property
    def Game(self):
        return Var(r'\Game')
    @property
    def backepsilon(self):
        return Var(r'\backepsilon')
    @property
    def imath(self):
        return Var(r'\imath')
    @property
    def jmath(self):
        return Var(r'\jmath')
    @property
    def ell(self):
        return Var(r'\ell')
    @property
    def Bbbk(self):
        return Var(r'\Bbbk')
    @property
    def amalg(self):
        return Var(r'\amalg')
    @property
    def nabla(self):
        return Var(r'\nabla')
    @property
    def mho(self):
        return Var(r'\mho')
    @property
    def partial(self):
        return Var(r'\partial')
    @property
    def eth(self):
        return Var(r'\eth')
    @property
    def hbar(self):
        return Var(r'\hbar')
    @property
    def hslash(self):
        return Var(r'\hslash')
    @property
    def Im(self):
        return Var(r'\Im')
    @property
    def Re(self):
        return Var(r'\Re')
    @property
    def wp(self):
        return Var(r'\wp')
    @property
    def emptyset(self):
        return Var(r'\emptyset')
    @property
    def emptyset(self):
        return Var(r'\emptyset')
    @property
    def varnothing(self):
        return Var(r'\varnothing')
    @property
    def complement(self):
        return Var(r'\complement')
    @property
    def circledS(self):
        return Var(r'\circledS')

# %%
#export
"default symbol lookup class, can change name later maybe"
Greek = GreekSymbols()

# %%
"TEST"

# %%
gs = GreekSymbols()
getWrappedProps(GreekSymbols, 'gs')

# %%
wrap(gs.beta | gs.gamma | gs.delta | gs.epsilon | gs.zeta | gs.eta | gs.theta | gs.iota | gs.kappa | gs.lambd | gs.mu | gs.nu | gs.xi | gs.mathrm | gs.pi | gs.rho | gs.sigma | gs.tau | gs.upsilon | gs.phi | gs.chi | gs.psi | gs.omega | gs.varepsilon | gs.vartheta | gs.varkappa | gs.varpi | gs.varrho | gs.varphi | gs.varsigma | gs.Gamma | gs.Delta | gs.Theta | gs.Lambda | gs.Upsilon | gs.Xi | gs.Phi | gs.Pi | gs.Psi | gs.Sigma | gs.Omega | gs.digamma | gs.aleph | gs.beth | gs.gimel | gs.daleth | gs.forall | gs.exists | gs.nexists | gs.Finv | gs.Game | gs.backepsilon | gs.imath | gs.jmath | gs.ell | gs.Bbbk | gs.amalg | gs.nabla | gs.mho | gs.partial | gs.eth | gs.hbar | gs.hslash | gs.Im | gs.Re | gs.wp | gs.emptyset | gs.varnothing | gs.complement | gs.circledS )

# %%
"EXTRACT"

# %%
pasta = r"""
    \alpha \alpha
    β {\displaystyle \beta } \beta \beta
    γ {\displaystyle \gamma } \gamma \gamma
    δ {\displaystyle \delta } \delta \delta
    ϵ {\displaystyle \epsilon } \epsilon \epsilon
    ζ {\displaystyle \zeta } \zeta \zeta

	

    η {\displaystyle \eta } \eta \eta
    θ {\displaystyle \theta } \theta \theta
    ι {\displaystyle \iota } \iota \iota
    κ {\displaystyle \kappa } \kappa \kappa
    λ {\displaystyle \lambda } \lambda \lambda
    μ {\displaystyle \mu } \mu \mu

	

    ν {\displaystyle \nu } \nu \nu
    ξ {\displaystyle \xi } \xi \xi
    o {\displaystyle \mathrm {o} } {\displaystyle \mathrm {o} } \omicron
    π {\displaystyle \pi } \pi \pi
    ρ {\displaystyle \rho } \rho \rho
    σ {\displaystyle \sigma } \sigma \sigma

	

    τ {\displaystyle \tau } \tau \tau
    υ {\displaystyle \upsilon } \upsilon \upsilon
    ϕ {\displaystyle \phi } \phi \phi
    χ {\displaystyle \chi } \chi \chi
    ψ {\displaystyle \psi } \psi \psi
    ω {\displaystyle \omega } \omega \omega

    ε {\displaystyle \varepsilon } \varepsilon \varepsilon
    ϑ {\displaystyle \vartheta } \vartheta \vartheta
    ϰ {\displaystyle \varkappa } \varkappa \varkappa
    ϖ {\displaystyle \varpi } \varpi \varpi
    ϱ {\displaystyle \varrho } \varrho \varrho
    φ {\displaystyle \varphi } \varphi \varphi
    ς {\displaystyle \varsigma } \varsigma \varsigma

	

    Γ {\displaystyle \Gamma } \Gamma \Gamma
    Δ {\displaystyle \Delta } \Delta \Delta
    Θ {\displaystyle \Theta } \Theta \Theta
    Λ {\displaystyle \Lambda } \Lambda \Lambda
    Υ {\displaystyle \Upsilon } \Upsilon \Upsilon
    Ξ {\displaystyle \Xi } \Xi \Xi
    Φ {\displaystyle \Phi } \Phi \Phi

	

    Π {\displaystyle \Pi } \Pi \Pi
    Ψ {\displaystyle \Psi } \Psi \Psi
    Σ {\displaystyle \Sigma } \Sigma \Sigma
    Ω {\displaystyle \Omega } \Omega \Omega
      {\displaystyle \ } \ 
    ϝ {\displaystyle \digamma } \digamma \digamma
      {\displaystyle \ } \ 

	

    ℵ {\displaystyle \aleph } \aleph \aleph
    ℶ {\displaystyle \beth } \beth \beth
    ℷ {\displaystyle \gimel } \gimel \gimel
    ℸ {\displaystyle \daleth } \daleth \daleth
      {\displaystyle \ } \ 
      {\displaystyle \ } \ 
      {\displaystyle \ } \ 

    ∀ {\displaystyle \forall } \forall \forall
    ∃ {\displaystyle \exists } \exists \exists
    ∄ {\displaystyle \nexists } \nexists \nexists
    Ⅎ {\displaystyle \Finv } \Finv \Finv
    ⅁ {\displaystyle \Game } \Game \Game
    ∍ {\displaystyle \backepsilon } \backepsilon \backepsilon

	

    ı {\displaystyle \imath } \imath \imath
    ȷ {\displaystyle \jmath } \jmath \jmath
    ℓ {\displaystyle \ell } \ell \ell
    k {\displaystyle \Bbbk } \Bbbk \Bbbk
    ⨿ {\displaystyle \amalg } \amalg \amalg
    ∇ {\displaystyle \nabla } \nabla \nabla
    ℧ {\displaystyle \mho } \mho \mho

	

    ∂ {\displaystyle \partial } \partial \partial
    ð {\displaystyle \eth } \eth \eth
    ℏ {\displaystyle \hbar } \hbar \hbar
    ℏ {\displaystyle \hslash } \hslash \hslash
    ℑ {\displaystyle \Im } \Im \Im
    ℜ {\displaystyle \Re } \Re \Re

	

    ℘ {\displaystyle \wp } \wp \wp
    ∅ {\displaystyle \emptyset } \O \O
    ∅ {\displaystyle \emptyset } \emptyset \emptyset
    ∅ {\displaystyle \varnothing } \varnothing \varnothing
    ∁ {\displaystyle \complement } \complement \complement
    Ⓢ {\displaystyle \circledS } \circledS \circledS
"""

# %%
from pytex.SymbolsExtractor import getDefs, getNameSym,getWrappedProps

# %%
getDefs(getNameSym(pasta))

# %%
! python3 ./notebook2script.py Greek.ipynb
