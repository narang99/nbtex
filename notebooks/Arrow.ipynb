# %%
#export
from pytex.Variable import Var
class ArrowsSymbols():
    def __init__(self):
        pass
    @property
    def Leftarrow(self):
        return Var(r'\Leftarrow')
    @property
    def leftharpoonup(self):
        return Var(r'\leftharpoonup')
    @property
    def leftharpoondown(self):
        return Var(r'\leftharpoondown')
    @property
    def leftleftarrows(self):
        return Var(r'\leftleftarrows')
    @property
    def rightarrow(self):
        return Var(r'\rightarrow')
    @property
    def Rightarrow(self):
        return Var(r'\Rightarrow')
    @property
    def rightharpoonup(self):
        return Var(r'\rightharpoonup')
    @property
    def rightharpoondown(self):
        return Var(r'\rightharpoondown')
    @property
    def rightrightarrows(self):
        return Var(r'\rightrightarrows')
    @property
    def uparrow(self):
        return Var(r'\uparrow')
    @property
    def Uparrow(self):
        return Var(r'\Uparrow')
    @property
    def upharpoonleft(self):
        return Var(r'\upharpoonleft')
    @property
    def upharpoonright(self):
        return Var(r'\upharpoonright')
    @property
    def upuparrows(self):
        return Var(r'\upuparrows')
    @property
    def downarrow(self):
        return Var(r'\downarrow')
    @property
    def Downarrow(self):
        return Var(r'\Downarrow')
    @property
    def downharpoonleft(self):
        return Var(r'\downharpoonleft')
    @property
    def downharpoonright(self):
        return Var(r'\downharpoonright')
    @property
    def downdownarrows(self):
        return Var(r'\downdownarrows')
    @property
    def longleftarrow(self):
        return Var(r'\longleftarrow')
    @property
    def Longleftarrow(self):
        return Var(r'\Longleftarrow')
    @property
    def hookleftarrow(self):
        return Var(r'\hookleftarrow')
    @property
    def leftrightharpoons(self):
        return Var(r'\leftrightharpoons')
    @property
    def leftrightarrows(self):
        return Var(r'\leftrightarrows')
    @property
    def Lleftarrow(self):
        return Var(r'\Lleftarrow')
    @property
    def Lsh(self):
        return Var(r'\Lsh')
    @property
    def leftarrowtail(self):
        return Var(r'\leftarrowtail')
    @property
    def twoheadleftarrow(self):
        return Var(r'\twoheadleftarrow')
    @property
    def curvearrowleft(self):
        return Var(r'\curvearrowleft')
    @property
    def circlearrowleft(self):
        return Var(r'\circlearrowleft')
    @property
    def looparrowleft(self):
        return Var(r'\looparrowleft')
    @property
    def longrightarrow(self):
        return Var(r'\longrightarrow')
    @property
    def Longrightarrow(self):
        return Var(r'\Longrightarrow')
    @property
    def hookrightarrow(self):
        return Var(r'\hookrightarrow')
    @property
    def rightleftharpoons(self):
        return Var(r'\rightleftharpoons')
    @property
    def rightleftarrows(self):
        return Var(r'\rightleftarrows')
    @property
    def Rrightarrow(self):
        return Var(r'\Rrightarrow')
    @property
    def Rsh(self):
        return Var(r'\Rsh')
    @property
    def rightarrowtail(self):
        return Var(r'\rightarrowtail')
    @property
    def twoheadrightarrow(self):
        return Var(r'\twoheadrightarrow')
    @property
    def curvearrowright(self):
        return Var(r'\curvearrowright')
    @property
    def circlearrowright(self):
        return Var(r'\circlearrowright')
    @property
    def looparrowright(self):
        return Var(r'\looparrowright')
    @property
    def leftrightarrow(self):
        return Var(r'\leftrightarrow')
    @property
    def longleftrightarrow(self):
        return Var(r'\longleftrightarrow')
    @property
    def updownarrow(self):
        return Var(r'\updownarrow')
    @property
    def nleftarrow(self):
        return Var(r'\nleftarrow')
    @property
    def nrightarrow(self):
        return Var(r'\nrightarrow')
    @property
    def nleftrightarrow(self):
        return Var(r'\nleftrightarrow')
    @property
    def Leftrightarrow(self):
        return Var(r'\Leftrightarrow')
    @property
    def Longleftrightarrow(self):
        return Var(r'\Longleftrightarrow')
    @property
    def Updownarrow(self):
        return Var(r'\Updownarrow')
    @property
    def nLeftarrow(self):
        return Var(r'\nLeftarrow')
    @property
    def nRightarrow(self):
        return Var(r'\nRightarrow')
    @property
    def nLeftrightarrow(self):
        return Var(r'\nLeftrightarrow')
    @property
    def mapsto(self):
        return Var(r'\mapsto')
    @property
    def longmapsto(self):
        return Var(r'\longmapsto')
    @property
    def multimap(self):
        return Var(r'\multimap')
    @property
    def rightsquigarrow(self):
        return Var(r'\rightsquigarrow')
    @property
    def leftrightsquigarrow(self):
        return Var(r'\leftrightsquigarrow')
    @property
    def swarrow(self):
        return Var(r'\swarrow')
    @property
    def searrow(self):
        return Var(r'\searrow')
    @property
    def nwarrow(self):
        return Var(r'\nwarrow')
    @property
    def nearrow(self):
        return Var(r'\nearrow')

# %%
#export
Arrow = ArrowsSymbols()

# %%
Arrow.nearrow
# Out:
# \nearrow

# %%
! python3 ./notebook2script.py Arrow.ipynb
# Out:
# Converted /home/default/Documents/py-latex/pytex/notebooks/Arrow.ipynb to /home/default/Documents/py-latex/pytex/pytex/Arrow.py

# %%
from pytex.SymbolsExtractor import getDefs, getNameSym, getWrappedProps

# %%
"TESTS"
# Out:
# 'TESTS'

# %%
from pytex.Variables import wrap
a = ArrowsSymbols()
getWrappedProps(ArrowsSymbols, 'a')
# Out:
# 'wrap(a.Leftarrow | a.leftharpoonup | a.leftharpoondown | a.leftleftarrows | a.rightarrow | a.Rightarrow | a.rightharpoonup | a.rightharpoondown | a.rightrightarrows | a.uparrow | a.Uparrow | a.upharpoonleft | a.upharpoonright | a.upuparrows | a.downarrow | a.Downarrow | a.downharpoonleft | a.downharpoonright | a.downdownarrows | a.longleftarrow | a.Longleftarrow | a.hookleftarrow | a.leftrightharpoons | a.leftrightarrows | a.Lleftarrow | a.Lsh | a.leftarrowtail | a.twoheadleftarrow | a.curvearrowleft | a.circlearrowleft | a.looparrowleft | a.longrightarrow | a.Longrightarrow | a.hookrightarrow | a.rightleftharpoons | a.rightleftarrows | a.Rrightarrow | a.Rsh | a.rightarrowtail | a.twoheadrightarrow | a.curvearrowright | a.circlearrowright | a.looparrowright | a.leftrightarrow | a.longleftrightarrow | a.updownarrow | a.nleftarrow | a.nrightarrow | a.nleftrightarrow | a.Leftrightarrow | a.Longleftrightarrow | a.Updownarrow | a.nLeftarrow | a.nRightarrow | a.nLeftrightarrow | a.mapsto 
# ...

# %%
wrap(a.Leftarrow | a.leftharpoonup | a.leftharpoondown | a.leftleftarrows | a.rightarrow | a.Rightarrow | a.rightharpoonup | a.rightharpoondown | a.rightrightarrows | a.uparrow | a.Uparrow | a.upharpoonleft | a.upharpoonright | a.upuparrows | a.downarrow | a.Downarrow | a.downharpoonleft | a.downharpoonright | a.downdownarrows | a.longleftarrow | a.Longleftarrow | a.hookleftarrow | a.leftrightharpoons | a.leftrightarrows | a.Lleftarrow | a.Lsh | a.leftarrowtail | a.twoheadleftarrow | a.curvearrowleft | a.circlearrowleft | a.looparrowleft | a.longrightarrow | a.Longrightarrow | a.hookrightarrow | a.rightleftharpoons | a.rightleftarrows | a.Rrightarrow | a.Rsh | a.rightarrowtail | a.twoheadrightarrow | a.curvearrowright | a.circlearrowright | a.looparrowright | a.leftrightarrow | a.longleftrightarrow | a.updownarrow | a.nleftarrow | a.nrightarrow | a.nleftrightarrow | a.Leftrightarrow | a.Longleftrightarrow | a.Updownarrow | a.nLeftarrow | a.nRightarrow | a.nLeftrightarrow | a.mapsto | a.longmapsto | a.multimap | a.rightsquigarrow | a.leftrightsquigarrow | a.swarrow | a.searrow | a.nwarrow | a.nearrow )
# Out:
# \begin{gather}\Leftarrow\hspace{1mm}\leftharpoonup\hspace{1mm}\leftharpoondown\hspace{1mm}\leftleftarrows\hspace{1mm}\rightarrow\hspace{1mm}\Rightarrow\hspace{1mm}\rightharpoonup\hspace{1mm}\rightharpoondown\hspace{1mm}\rightrightarrows\hspace{1mm}\uparrow\hspace{1mm}\Uparrow\hspace{1mm}\upharpoonleft\hspace{1mm}\upharpoonright\hspace{1mm}\upuparrows\hspace{1mm}\downarrow\hspace{1mm}\Downarrow\hspace{1mm}\downharpoonleft\hspace{1mm}\downharpoonright\hspace{1mm}\downdownarrows\hspace{1mm}\longleftarrow\hspace{1mm}\Longleftarrow\hspace{1mm}\hookleftarrow\hspace{1mm}\leftrightharpoons\hspace{1mm}\leftrightarrows\hspace{1mm}\Lleftarrow\hspace{1mm}\Lsh\hspace{1mm}\leftarrowtail\hspace{1mm}\twoheadleftarrow\hspace{1mm}\curvearrowleft\hspace{1mm}\circlearrowleft\hspace{1mm}\looparrowleft\hspace{1mm}\longrightarrow\hspace{1mm}\Longrightarrow\hspace{1mm}\hookrightarrow\hspace{1mm}\rightleftharpoons\hspace{1mm}\rightleftarrows\hspace{1mm}\Rrightarrow\hspace{1mm}\Rsh\hspace{1mm}\rightarrowtail\
# ...

# %%
" EXTRACTION "
# Out:
# ' EXTRACTION '

# %%
getDefs(getNameSym(pasta))
# Out:
# @property
# def Leftarrow(self):
#     return Var(r'\Leftarrow')
# @property
# def leftharpoonup(self):
#     return Var(r'\leftharpoonup')
# @property
# def leftharpoondown(self):
#     return Var(r'\leftharpoondown')
# @property
# def leftleftarrows(self):
#     return Var(r'\leftleftarrows')
# @property
# def rightarrow(self):
#     return Var(r'\rightarrow')
# @property
# def Rightarrow(self):
#     return Var(r'\Rightarrow')
# @property
# def rightharpoonup(self):
#     return Var(r'\rightharpoonup')
# @property
# def rightharpoondown(self):
#     return Var(r'\rightharpoondown')
# @property
# def rightrightarrows(self):
#     return Var(r'\rightrightarrows')
# @property
# def uparrow(self):
#     return Var(r'\uparrow')
# @property
# def Uparrow(self):
#     return Var(r'\Uparrow')
# @property
# def upharpoonleft(self):
#     return Var(r'\upharpoonleft')
# @property
# def upharpoonright(self):
#     return Var(r'\upharpoonright')
# @property
# def upuparrows(self):
# ...

# %%
pasta = r"""
    \leftarrow \leftarrow
    ⇐ {\displaystyle \Leftarrow } \Leftarrow \Leftarrow
    ↼ {\displaystyle \leftharpoonup } \leftharpoonup \leftharpoonup
    ↽ {\displaystyle \leftharpoondown } \leftharpoondown \leftharpoondown
    ⇇ {\displaystyle \leftleftarrows } \leftleftarrows \leftleftarrows

	

    → {\displaystyle \rightarrow } \rightarrow \rightarrow
    ⇒ {\displaystyle \Rightarrow } \Rightarrow \Rightarrow
    ⇀ {\displaystyle \rightharpoonup } \rightharpoonup \rightharpoonup
    ⇁ {\displaystyle \rightharpoondown } \rightharpoondown \rightharpoondown
    ⇉ {\displaystyle \rightrightarrows } \rightrightarrows \rightrightarrows

	

    ↑ {\displaystyle \uparrow } \uparrow \uparrow
    ⇑ {\displaystyle \Uparrow } \Uparrow \Uparrow
    ↿ {\displaystyle \upharpoonleft } \upharpoonleft \upharpoonleft
    ↾ {\displaystyle \upharpoonright } \upharpoonright \upharpoonright
    ⇈ {\displaystyle \upuparrows } \upuparrows \upuparrows

	

    ↓ {\displaystyle \downarrow } \downarrow \downarrow
    ⇓ {\displaystyle \Downarrow } \Downarrow \Downarrow
    ⇃ {\displaystyle \downharpoonleft } \downharpoonleft \downharpoonleft
    ⇂ {\displaystyle \downharpoonright } \downharpoonright \downharpoonright
    ⇊ {\displaystyle \downdownarrows } \downdownarrows \downdownarrows

    ⟵ {\displaystyle \longleftarrow } \longleftarrow \longleftarrow
    ⟸ {\displaystyle \Longleftarrow } \Longleftarrow \Longleftarrow
    ↩ {\displaystyle \hookleftarrow } \hookleftarrow \hookleftarrow
    ⇋ {\displaystyle \leftrightharpoons } \leftrightharpoons \leftrightharpoons
    ⇆ {\displaystyle \leftrightarrows } \leftrightarrows \leftrightarrows
    ⇚ {\displaystyle \Lleftarrow } \Lleftarrow \Lleftarrow
    ↰ {\displaystyle \Lsh } \Lsh \Lsh
    ↢ {\displaystyle \leftarrowtail } \leftarrowtail \leftarrowtail
    ↞ {\displaystyle \twoheadleftarrow } \twoheadleftarrow \twoheadleftarrow
    ↶ {\displaystyle \curvearrowleft } \curvearrowleft \curvearrowleft
    ↺ {\displaystyle \circlearrowleft } \circlearrowleft \circlearrowleft
    ↫ {\displaystyle \looparrowleft } \looparrowleft \looparrowleft

	

    ⟶ {\displaystyle \longrightarrow } \longrightarrow \longrightarrow
    ⟹ {\displaystyle \Longrightarrow } \Longrightarrow \Longrightarrow
    ↪ {\displaystyle \hookrightarrow } \hookrightarrow \hookrightarrow
    ⇌ {\displaystyle \rightleftharpoons } \rightleftharpoons \rightleftharpoons
    ⇄ {\displaystyle \rightleftarrows } \rightleftarrows \rightleftarrows
    ⇛ {\displaystyle \Rrightarrow } \Rrightarrow \Rrightarrow
    ↱ {\displaystyle \Rsh } \Rsh \Rsh
    ↣ {\displaystyle \rightarrowtail } \rightarrowtail \rightarrowtail
    ↠ {\displaystyle \twoheadrightarrow } \twoheadrightarrow \twoheadrightarrow
    ↷ {\displaystyle \curvearrowright } \curvearrowright \curvearrowright
    ↻ {\displaystyle \circlearrowright } \circlearrowright \circlearrowright
    ↬ {\displaystyle \looparrowright } \looparrowright \looparrowright

    ↔ {\displaystyle \leftrightarrow } \leftrightarrow \leftrightarrow
    ⟷ {\displaystyle \longleftrightarrow } \longleftrightarrow \longleftrightarrow
    ↕ {\displaystyle \updownarrow } \updownarrow \updownarrow
    ↚ {\displaystyle \nleftarrow } \nleftarrow \nleftarrow
    ↛ {\displaystyle \nrightarrow } \nrightarrow \nrightarrow
    ↮ {\displaystyle \nleftrightarrow } \nleftrightarrow \nleftrightarrow

	

    ⇔ {\displaystyle \Leftrightarrow } \Leftrightarrow \Leftrightarrow
    ⟺ {\displaystyle \Longleftrightarrow } \Longleftrightarrow \Longleftrightarrow
    ⇕ {\displaystyle \Updownarrow } \Updownarrow \Updownarrow
    ⇍ {\displaystyle \nLeftarrow } \nLeftarrow \nLeftarrow
    ⇏ {\displaystyle \nRightarrow } \nRightarrow \nRightarrow
    ⇎ {\displaystyle \nLeftrightarrow } \nLeftrightarrow \nLeftrightarrow

	

    ↦ {\displaystyle \mapsto } \mapsto \mapsto
    ⟼ {\displaystyle \longmapsto } \longmapsto \longmapsto
    ⊸ {\displaystyle \multimap } \multimap \multimap
      {\displaystyle \ } \ 
    ⇝ {\displaystyle \rightsquigarrow } \rightsquigarrow \rightsquigarrow
    ↭ {\displaystyle \leftrightsquigarrow } \leftrightsquigarrow \leftrightsquigarrow

    ↙ {\displaystyle \swarrow } \swarrow \swarrow

	

    ↘ {\displaystyle \searrow } \searrow \searrow

	

    ↖ {\displaystyle \nwarrow } \nwarrow \nwarrow

	

    ↗ {\displaystyle \nearrow } \nearrow \nearrow
"""
