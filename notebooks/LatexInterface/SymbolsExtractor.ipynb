# %%
#export
"Methods for extracting properties from: https://en.wikipedia.org/wiki/Wikipedia:LaTeX_symbols"
import re
def getNameSym(pasta):
    lst = []
    for l in pasta.split('\n'):
        r = re.search('{.*}', l)
        if r is not None:
            p = r.group()[1:-1]
            ps = p.split(' ')
            if len(ps) > 1 and ps[1] != '\\':
                lst.append(ps[1])
    return [(arg[1:], arg) for arg in lst]

# %%
#export
def getDefs(l):
    for name,ap in l:
        name = ap[1:]
        print(f"""@property
def {name}(self):
    return Var(r'{ap}')""")

# %%
#export

def getProps(cl):
    l = []
    for v in vars(cl):    
        if isinstance(vars(cl)[v], property): l.append(v)
    return l

def getWrappedProps(cl, objName):
    op = cl()
    l = getProps(cl)
    s = ''
    for name in l:
        s += f"{objName}.{name} | "
    sx = f"wrap({s[:-2]})"
    s = "{{" + f"wrap({s[:-2]})" + "}}"
    return sx

# %%
! python3 ../notebook2script.py SymbolsExtractor.ipynb
# Out:
# Converted /home/default/Documents/py-latex/pytex/notebooks/LatexInterface/SymbolsExtractor.ipynb to /home/default/Documents/py-latex/pytex/pytex/LatexInterface/SymbolsExtractor.py

# %%
getDefs(getNameSym(pasta))
# Out:
# @property
# def leq(self):
#     return Var('\leq')
# @property
# def leqq(self):
#     return Var('\leqq')
# @property
# def leqslant(self):
#     return Var('\leqslant')
# @property
# def (self):
#     return Var('>')
# @property
# def geq(self):
#     return Var('\geq')
# @property
# def geqq(self):
#     return Var('\geqq')
# @property
# def geqslant(self):
#     return Var('\geqslant')
# @property
# def nless(self):
#     return Var('\nless')
# @property
# def nleq(self):
#     return Var('\nleq')
# @property
# def lneq(self):
#     return Var('\lneq')
# @property
# def nleqq(self):
#     return Var('\nleqq')
# @property
# def lneqq(self):
#     return Var('\lneqq')
# @property
# def lvertneqq(self):
#     return Var('\lvertneqq')
# @property
# def nleqslant(self):
#     return Var('\nleqslant')
# @property
# def ngtr(self):
#     return Var('\ngtr')
# @property
# def ngeq(self):
#     return Var('\ngeq')
# @property
# def gneq(self):
#     return Var('\gneq')
# @property
# def ngeqq(self):
#     return Var('\ngeqq')
# @property
# def gneqq(self):
#     return Var('\gneqq')
# @property
# def gvertneqq(self):
#     return Var('\gvertneqq')
# @property
# def ngeqslant(self):
#     return Var('\ngeqslant')
# @property
# def vartriangleleft(self):
#     return Var('\vartriangleleft')
# @property
# def trianglelefteq(self):
#     return Var('\trianglelefteq')
# @property
# def lesssim(self):
#     return Var('\lesssim')
# @property
# def lessapprox(self):
#     return Var('\lessapprox')
# @property
# def prec(self):
#     return Var('\prec')
# @property
# def preceq(self):
#     return Var('\preceq')
# @property
# def precsim(self):
#     return Var('\precsim')
# @property
# def precapprox(self):
#     return Var('\precapprox')
# @property
# def vartriangleright(self):
#     return Var('\vartriangleright')
# @property
# def trianglerighteq(self):
#     return Var('\trianglerighteq')
# @property
# def gtrsim(self):
#     return Var('\gtrsim')
# @property
# def gtrapprox(self):
#     return Var('\gtrapprox')
# @property
# def succ(self):
#     return Var('\succ')
# @property
# def succeq(self):
#     return Var('\succeq')
# @property
# def succsim(self):
#     return Var('\succsim')
# @property
# def succapprox(self):
#     return Var('\succapprox')
# @property
# def ntriangleleft(self):
#     return Var('\ntriangleleft')
# @property
# def ntrianglelefteq(self):
#     return Var('\ntrianglelefteq')
# @property
# def lnsim(self):
#     return Var('\lnsim')
# @property
# def lnapprox(self):
#     return Var('\lnapprox')
# @property
# def nprec(self):
#     return Var('\nprec')
# @property
# def npreceq(self):
#     return Var('\npreceq')
# @property
# def precnsim(self):
#     return Var('\precnsim')
# @property
# def precnapprox(self):
#     return Var('\precnapprox')
# @property
# def ntriangleright(self):
#     return Var('\ntriangleright')
# @property
# def ntrianglerighteq(self):
#     return Var('\ntrianglerighteq')
# @property
# def gnsim(self):
#     return Var('\gnsim')
# @property
# def gnapprox(self):
#     return Var('\gnapprox')
# @property
# def nsucc(self):
#     return Var('\nsucc')
# @property
# def nsucceq(self):
#     return Var('\nsucceq')
# @property
# def succnsim(self):
#     return Var('\succnsim')
# @property
# def succnapprox(self):
#     return Var('\succnapprox')
# @property
# def eqslantless(self):
#     return Var('\eqslantless')
# @property
# def lessgtr(self):
#     return Var('\lessgtr')
# @property
# def lesseqgtr(self):
#     return Var('\lesseqgtr')
# @property
# def lesseqqgtr(self):
#     return Var('\lesseqqgtr')
# @property
# def eqslantgtr(self):
#     return Var('\eqslantgtr')
# @property
# def gtrless(self):
#     return Var('\gtrless')
# @property
# def gtreqless(self):
#     return Var('\gtreqless')
# @property
# def gtreqqless(self):
#     return Var('\gtreqqless')
# @property
# def ll(self):
#     return Var('\ll')
# @property
# def lll(self):
#     return Var('\lll')
# @property
# def lessdot(self):
#     return Var('\lessdot')
# @property
# def preccurlyeq(self):
#     return Var('\preccurlyeq')
# @property
# def curlyeqprec(self):
#     return Var('\curlyeqprec')
# @property
# def gg(self):
#     return Var('\gg')
# @property
# def ggg(self):
#     return Var('\ggg')
# @property
# def gtrdot(self):
#     return Var('\gtrdot')
# @property
# def succcurlyeq(self):
#     return Var('\succcurlyeq')
# @property
# def curlyeqsucc(self):
#     return Var('\curlyeqsucc')

# %%
pasta = r"""
     <
    ≤ {\displaystyle \leq } \leq \leq
      {\displaystyle \ } \ 
    ≦ {\displaystyle \leqq } \leqq \leqq
      {\displaystyle \ } \ 
      {\displaystyle \ } \ 
    ⩽ {\displaystyle \leqslant } \leqslant \leqslant

	

    > {\displaystyle >} > >
    ≥ {\displaystyle \geq } \geq \geq
      {\displaystyle \ } \ 
    ≧ {\displaystyle \geqq } \geqq \geqq
      {\displaystyle \ } \ 
      {\displaystyle \ } \ 
    ⩾ {\displaystyle \geqslant } \geqslant \geqslant

	

    ≮ {\displaystyle \nless } \nless \nless
    ≰ {\displaystyle \nleq } \nleq \nleq
    ⪇ {\displaystyle \lneq } \lneq \lneq
    ≰ {\displaystyle \nleqq } \nleqq \nleqq
    ≨ {\displaystyle \lneqq } \lneqq \lneqq
    ≨ {\displaystyle \lvertneqq } \lvertneqq \lvertneqq
    ⪇ {\displaystyle \nleqslant } \nleqslant \nleqslant

	

    ≯ {\displaystyle \ngtr } \ngtr \ngtr
    ≱ {\displaystyle \ngeq } \ngeq \ngeq
    ⪈ {\displaystyle \gneq } \gneq \gneq
    ≱ {\displaystyle \ngeqq } \ngeqq \ngeqq
    ≩ {\displaystyle \gneqq } \gneqq \gneqq
    ≩ {\displaystyle \gvertneqq } \gvertneqq \gvertneqq
    ⪈ {\displaystyle \ngeqslant } \ngeqslant \ngeqslant

    ⊲ {\displaystyle \vartriangleleft } \vartriangleleft \vartriangleleft
    ⊴ {\displaystyle \trianglelefteq } \trianglelefteq \trianglelefteq
    ≲ {\displaystyle \lesssim } \lesssim \lesssim
    ⪅ {\displaystyle \lessapprox } \lessapprox \lessapprox
    ≺ {\displaystyle \prec } \prec \prec
    ⪯ {\displaystyle \preceq } \preceq \preceq
    ≾ {\displaystyle \precsim } \precsim \precsim
    ⪷ {\displaystyle \precapprox } \precapprox \precapprox

	

    ⊳ {\displaystyle \vartriangleright } \vartriangleright \vartriangleright
    ⊵ {\displaystyle \trianglerighteq } \trianglerighteq \trianglerighteq
    ≳ {\displaystyle \gtrsim } \gtrsim \gtrsim
    ⪆ {\displaystyle \gtrapprox } \gtrapprox \gtrapprox
    ≻ {\displaystyle \succ } \succ \succ
    ⪰ {\displaystyle \succeq } \succeq \succeq
    ≿ {\displaystyle \succsim } \succsim \succsim
    ⪸ {\displaystyle \succapprox } \succapprox \succapprox

	

    ⋪ {\displaystyle \ntriangleleft } \ntriangleleft \ntriangleleft
    ⋬ {\displaystyle \ntrianglelefteq } \ntrianglelefteq \ntrianglelefteq
    ⋦ {\displaystyle \lnsim } \lnsim \lnsim
    ⪉ {\displaystyle \lnapprox } \lnapprox \lnapprox
    ⊀ {\displaystyle \nprec } \nprec \nprec
    ⋠ {\displaystyle \npreceq } \npreceq \npreceq
    ⋨ {\displaystyle \precnsim } \precnsim \precnsim
    ⪹ {\displaystyle \precnapprox } \precnapprox \precnapprox

	

    ⋫ {\displaystyle \ntriangleright } \ntriangleright \ntriangleright
    ⋭ {\displaystyle \ntrianglerighteq } \ntrianglerighteq \ntrianglerighteq
    ⋧ {\displaystyle \gnsim } \gnsim \gnsim
    ⪊ {\displaystyle \gnapprox } \gnapprox \gnapprox
    ⊁ {\displaystyle \nsucc } \nsucc \nsucc
    ⋡ {\displaystyle \nsucceq } \nsucceq \nsucceq
    ⋩ {\displaystyle \succnsim } \succnsim \succnsim
    ⪺ {\displaystyle \succnapprox } \succnapprox \succnapprox

    ⪕ {\displaystyle \eqslantless } \eqslantless \eqslantless
    ≶ {\displaystyle \lessgtr } \lessgtr \lessgtr
    ⋚ {\displaystyle \lesseqgtr } \lesseqgtr \lesseqgtr
    ⪋ {\displaystyle \lesseqqgtr } \lesseqqgtr \lesseqqgtr

	

    ⪖ {\displaystyle \eqslantgtr } \eqslantgtr \eqslantgtr
    ≷ {\displaystyle \gtrless } \gtrless \gtrless
    ⋛ {\displaystyle \gtreqless } \gtreqless \gtreqless
    ⪌ {\displaystyle \gtreqqless } \gtreqqless \gtreqqless

	

    ≪ {\displaystyle \ll } \ll \ll
    ⋘ {\displaystyle \lll } \lll \lll
    ⋖ {\displaystyle \lessdot } \lessdot \lessdot
    ≼ {\displaystyle \preccurlyeq } \preccurlyeq \preccurlyeq
    ⋞ {\displaystyle \curlyeqprec } \curlyeqprec \curlyeqprec

	

    ≫ {\displaystyle \gg } \gg \gg
    ⋙ {\displaystyle \ggg } \ggg \ggg
    ⋗ {\displaystyle \gtrdot } \gtrdot \gtrdot
    ≽ {\displaystyle \succcurlyeq } \succcurlyeq \succcurlyeq
    ⋟ {\displaystyle \curlyeqsucc } \curlyeqsucc \curlyeqsucc
"""

# %%
getNameSym(pasta)
# Out:
# [('leq', '\\leq'),
#  ('leqq', '\\leqq'),
#  ('leqslant', '\\leqslant'),
#  ('', '>'),
#  ('geq', '\\geq'),
#  ('geqq', '\\geqq'),
#  ('geqslant', '\\geqslant'),
#  ('nless', '\\nless'),
#  ('nleq', '\\nleq'),
#  ('lneq', '\\lneq'),
#  ('nleqq', '\\nleqq'),
#  ('lneqq', '\\lneqq'),
#  ('lvertneqq', '\\lvertneqq'),
#  ('nleqslant', '\\nleqslant'),
#  ('ngtr', '\\ngtr'),
#  ('ngeq', '\\ngeq'),
#  ('gneq', '\\gneq'),
#  ('ngeqq', '\\ngeqq'),
#  ('gneqq', '\\gneqq'),
#  ('gvertneqq', '\\gvertneqq'),
#  ('ngeqslant', '\\ngeqslant'),
#  ('vartriangleleft', '\\vartriangleleft'),
#  ('trianglelefteq', '\\trianglelefteq'),
#  ('lesssim', '\\lesssim'),
#  ('lessapprox', '\\lessapprox'),
#  ('prec', '\\prec'),
#  ('preceq', '\\preceq'),
#  ('precsim', '\\precsim'),
#  ('precapprox', '\\precapprox'),
#  ('vartriangleright', '\\vartriangleright'),
#  ('trianglerighteq', '\\trianglerighteq'),
#  ('gtrsim', '\\gtrsim'),
#  ('gtrapprox', '\\gtrapprox'),
#  ('succ', '\\succ'),
#  ('succeq', '\\succeq'),
#  ('succsim', '\\succsim'),
#  ('succapprox', '\\succapprox'),
#  ('ntriangleleft', '\\ntriangleleft'),
#  ('ntrianglelefteq', '\\ntrianglelefteq'),
#  ('lnsim', '\\lnsim'),
#  ('lnapprox', '\\lnapprox'),
#  ('nprec', '\\nprec'),
#  ('npreceq', '\\npreceq'),
#  ('precnsim', '\\precnsim'),
#  ('precnapprox', '\\precnapprox'),
#  ('ntriangleright', '\\ntriangleright'),
#  ('ntrianglerighteq', '\\ntrianglerighteq'),
#  ('gnsim', '\\gnsim'),
#  ('gnapprox', '\\gnapprox'),
#  ('nsucc', '\\nsucc'),
#  ('nsucceq', '\\nsucceq'),
#  ('succnsim', '\\succnsim'),
#  ('succnapprox', '\\succnapprox'),
#  ('eqslantless', '\\eqslantless'),
#  ('lessgtr', '\\lessgtr'),
#  ('lesseqgtr', '\\lesseqgtr'),
#  ('lesseqqgtr', '\\lesseqqgtr'),
#  ('eqslantgtr', '\\eqslantgtr'),
#  ('gtrless', '\\gtrless'),
#  ('gtreqless', '\\gtreqless'),
#  ('gtreqqless', '\\gtreqqless'),
#  ('ll', '\\ll'),
#  ('lll', '\\lll'),
#  ('lessdot', '\\lessdot'),
#  ('preccurlyeq', '\\preccurlyeq'),
#  ('curlyeqprec', '\\curlyeqprec'),
#  ('gg', '\\gg'),
#  ('ggg', '\\ggg'),
#  ('gtrdot', '\\gtrdot'),
#  ('succcurlyeq', '\\succcurlyeq'),
#  ('curlyeqsucc', '\\curlyeqsucc')]

# %%
from exp.Variables import wrap, Var

# %%
v = Var('\\leq')
wrap(v)
# Out:
# \begin{gather}\leq\end{gather}
