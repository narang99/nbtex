# %%
#export 
class GreekSymbols():
    def __init__(self):
        pass
    @property
    def alpha(self):
        return r'\alpha'
    @property
    def beta(self):
        return (r'\beta')
    @property
    def gamma(self):
        return (r'\gamma')
    @property
    def delta(self):
        return (r'\delta')
    @property
    def epsilon(self):
        return (r'\epsilon')
    @property
    def zeta(self):
        return (r'\zeta')
    @property
    def eta(self):
        return (r'\eta')
    @property
    def theta(self):
        return (r'\theta')
    @property
    def iota(self):
        return (r'\iota')
    @property
    def kappa(self):
        return (r'\kappa')
    @property
    def lambd(self):
        return (r'\lambda')
    @property
    def mu(self):
        return (r'\mu')
    @property
    def nu(self):
        return (r'\nu')
    @property
    def xi(self):
        return (r'\xi')
    @property
    def mathrm(self):
        return (r'\mathrm')
    @property
    def pi(self):
        return (r'\pi')
    @property
    def rho(self):
        return (r'\rho')
    @property
    def sigma(self):
        return (r'\sigma')
    @property
    def tau(self):
        return (r'\tau')
    @property
    def upsilon(self):
        return (r'\upsilon')
    @property
    def phi(self):
        return (r'\phi')
    @property
    def chi(self):
        return (r'\chi')
    @property
    def psi(self):
        return (r'\psi')
    @property
    def omega(self):
        return (r'\omega')
    @property
    def varepsilon(self):
        return (r'\varepsilon')
    @property
    def vartheta(self):
        return (r'\vartheta')
    @property
    def varkappa(self):
        return (r'\varkappa')
    @property
    def varpi(self):
        return (r'\varpi')
    @property
    def varrho(self):
        return (r'\varrho')
    @property
    def varphi(self):
        return (r'\varphi')
    @property
    def varsigma(self):
        return (r'\varsigma')
    @property
    def Gamma(self):
        return (r'\Gamma')
    @property
    def Delta(self):
        return (r'\Delta')
    @property
    def Theta(self):
        return (r'\Theta')
    @property
    def Lambda(self):
        return (r'\Lambda')
    @property
    def Upsilon(self):
        return (r'\Upsilon')
    @property
    def Xi(self):
        return (r'\Xi')
    @property
    def Phi(self):
        return (r'\Phi')
    @property
    def Pi(self):
        return (r'\Pi')
    @property
    def Psi(self):
        return (r'\Psi')
    @property
    def Sigma(self):
        return (r'\Sigma')
    @property
    def Omega(self):
        return (r'\Omega')
    @property
    def digamma(self):
        return (r'\digamma')
    @property
    def aleph(self):
        return (r'\aleph')
    @property
    def beth(self):
        return (r'\beth')
    @property
    def gimel(self):
        return (r'\gimel')
    @property
    def daleth(self):
        return (r'\daleth')
    @property
    def forall(self):
        return (r'\forall')
    @property
    def exists(self):
        return (r'\exists')
    @property
    def nexists(self):
        return (r'\nexists')
    @property
    def Finv(self):
        return (r'\Finv')
    @property
    def Game(self):
        return (r'\Game')
    @property
    def backepsilon(self):
        return (r'\backepsilon')
    @property
    def imath(self):
        return (r'\imath')
    @property
    def jmath(self):
        return (r'\jmath')
    @property
    def ell(self):
        return (r'\ell')
    @property
    def Bbbk(self):
        return (r'\Bbbk')
    @property
    def amalg(self):
        return (r'\amalg')
    @property
    def nabla(self):
        return (r'\nabla')
    @property
    def mho(self):
        return (r'\mho')
    @property
    def partial(self):
        return (r'\partial')
    @property
    def eth(self):
        return (r'\eth')
    @property
    def hbar(self):
        return (r'\hbar')
    @property
    def hslash(self):
        return (r'\hslash')
    @property
    def Im(self):
        return (r'\Im')
    @property
    def Re(self):
        return (r'\Re')
    @property
    def wp(self):
        return (r'\wp')
    @property
    def emptyset(self):
        return (r'\emptyset')
    @property
    def emptyset(self):
        return (r'\emptyset')
    @property
    def varnothing(self):
        return (r'\varnothing')
    @property
    def complement(self):
        return (r'\complement')
    @property
    def circledS(self):
        return (r'\circledS')

# %%
#export
"default symbol lookup class, can change name later maybe"
Greek = GreekSymbols()

# %% [markdown]
# $\alpha$

# %%
! python3 ../notebook2script.py Greek.ipynb
# Out:
# Converted /home/default/Documents/py-latex/nbtex/notebooks/LatexInterface/Greek.ipynb to /home/default/Documents/py-latex/nbtex/nbtex/LatexInterface/Greek.py

# %%
r"""
    \alpha \alpha
    β {\displaystyle \beta } \beta \beta
    γ {\displaystyle \gamma } \gamma \gamma
    δ {\displaystyle \delta } \delta \delta
    ϵ {\displaystyle \epsilon } \epsilon \epsilon
    ζ {\displaystyle \zeta } \zeta \zeta

	

    η {\displaystyle \eta } \eta \eta
    θ {\displaystyle \theta } \theta \theta
    ι {\displaystyle \iota } \iota \iota
    κ {\displaystyle \kappa } \kappa \kappa
    λ {\displaystyle \lambda } \lambda \lambda
    μ {\displaystyle \mu } \mu \mu

	

    ν {\displaystyle \nu } \nu \nu
    ξ {\displaystyle \xi } \xi \xi
    o {\displaystyle \mathrm {o} } {\displaystyle \mathrm {o} } \omicron
    π {\displaystyle \pi } \pi \pi
    ρ {\displaystyle \rho } \rho \rho
    σ {\displaystyle \sigma } \sigma \sigma

	

    τ {\displaystyle \tau } \tau \tau
    υ {\displaystyle \upsilon } \upsilon \upsilon
    ϕ {\displaystyle \phi } \phi \phi
    χ {\displaystyle \chi } \chi \chi
    ψ {\displaystyle \psi } \psi \psi
    ω {\displaystyle \omega } \omega \omega

    ε {\displaystyle \varepsilon } \varepsilon \varepsilon
    ϑ {\displaystyle \vartheta } \vartheta \vartheta
    ϰ {\displaystyle \varkappa } \varkappa \varkappa
    ϖ {\displaystyle \varpi } \varpi \varpi
    ϱ {\displaystyle \varrho } \varrho \varrho
    φ {\displaystyle \varphi } \varphi \varphi
    ς {\displaystyle \varsigma } \varsigma \varsigma

	

    Γ {\displaystyle \Gamma } \Gamma \Gamma
    Δ {\displaystyle \Delta } \Delta \Delta
    Θ {\displaystyle \Theta } \Theta \Theta
    Λ {\displaystyle \Lambda } \Lambda \Lambda
    Υ {\displaystyle \Upsilon } \Upsilon \Upsilon
    Ξ {\displaystyle \Xi } \Xi \Xi
    Φ {\displaystyle \Phi } \Phi \Phi

	

    Π {\displaystyle \Pi } \Pi \Pi
    Ψ {\displaystyle \Psi } \Psi \Psi
    Σ {\displaystyle \Sigma } \Sigma \Sigma
    Ω {\displaystyle \Omega } \Omega \Omega
      {\displaystyle \ } \ 
    ϝ {\displaystyle \digamma } \digamma \digamma
      {\displaystyle \ } \ 

	

    ℵ {\displaystyle \aleph } \aleph \aleph
    ℶ {\displaystyle \beth } \beth \beth
    ℷ {\displaystyle \gimel } \gimel \gimel
    ℸ {\displaystyle \daleth } \daleth \daleth
      {\displaystyle \ } \ 
      {\displaystyle \ } \ 
      {\displaystyle \ } \ 

    ∀ {\displaystyle \forall } \forall \forall
    ∃ {\displaystyle \exists } \exists \exists
    ∄ {\displaystyle \nexists } \nexists \nexists
    Ⅎ {\displaystyle \Finv } \Finv \Finv
    ⅁ {\displaystyle \Game } \Game \Game
    ∍ {\displaystyle \backepsilon } \backepsilon \backepsilon

	

    ı {\displaystyle \imath } \imath \imath
    ȷ {\displaystyle \jmath } \jmath \jmath
    ℓ {\displaystyle \ell } \ell \ell
    k {\displaystyle \Bbbk } \Bbbk \Bbbk
    ⨿ {\displaystyle \amalg } \amalg \amalg
    ∇ {\displaystyle \nabla } \nabla \nabla
    ℧ {\displaystyle \mho } \mho \mho

	

    ∂ {\displaystyle \partial } \partial \partial
    ð {\displaystyle \eth } \eth \eth
    ℏ {\displaystyle \hbar } \hbar \hbar
    ℏ {\displaystyle \hslash } \hslash \hslash
    ℑ {\displaystyle \Im } \Im \Im
    ℜ {\displaystyle \Re } \Re \Re

	

    ℘ {\displaystyle \wp } \wp \wp
    ∅ {\displaystyle \emptyset } \O \O
    ∅ {\displaystyle \emptyset } \emptyset \emptyset
    ∅ {\displaystyle \varnothing } \varnothing \varnothing
    ∁ {\displaystyle \complement } \complement \complement
    Ⓢ {\displaystyle \circledS } \circledS \circledS

    a ´ {\displaystyle {\acute {a}}} \acute{a} \acute{a}
    a ^ {\displaystyle {\hat {a}}} \hat{a} \hat{a}
    a ¨ {\displaystyle {\ddot {a}}} \ddot{a} \ddot{a}
    a ¯ {\displaystyle {\bar {a}}} \bar{a} \bar{a}
    a ~ {\displaystyle {\tilde {a}}} \tilde{a} \tilde{a}

	

    a ` {\displaystyle {\grave {a}}} \grave{a} \grave{a}
    a ˇ {\displaystyle {\check {a}}} \check{a} \check{a}
    a ˙ {\displaystyle {\dot {a}}} \dot{a} \dot{a}
    a ˘ {\displaystyle {\breve {a}}} \breve{a} \breve{a}
    a → {\displaystyle {\vec {a}}} \vec{a} \vec{a}

	

    ′ {\displaystyle \prime } \prime \prime
    ‵ {\displaystyle \backprime } \backprime \backprime
    ¶ {\displaystyle \P } \P \P
    § {\displaystyle \S } \S \S
    Å {\displaystyle \mathrm {\AA} } \AA \AA
"""
